# %% [raw]
# <style type="text/css">
# .input_prompt, .input_area, .output_prompt {
#     display:none !important;
# }
#
# div.output_png {
#   display: flex;
#   justify-content: center;
# }
# </style>

# %% [raw]
# <script type="text/javascript">
#
# $(document).ready(function(){
#
#     Reveal.configure({
#         transition: 'none' // none/fade/slide/convex/concave/zoom
#     })
# });
# </script>

# %%
# %matplotlib notebook
import numpy as np
import ijroi
import glob
import tifffile
from scipy.interpolate import Rbf
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import ipyvolume.pylab as p3
import plotly.plotly as py
import plotly.graph_objs as go
#from plotly.tools import figure_factory as FF
from skimage import measure
import plotly
plotly.offline.init_notebook_mode()
# Out:
# <script type='text/javascript'>if(!window.Plotly){define('plotly', function(require, exports, module) {/**
# * plotly.js v1.20.5
# * Copyright 2012-2016, Plotly, Inc.
# * All rights reserved.
# * Licensed under the MIT license
# */
# ...

# %%
# %matplotlib notebook
import numpy as np
import ijroi
import glob
from scipy.interpolate import Rbf
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import ipyvolume.pylab as p3
import plotly.plotly as py
import plotly.graph_objs as go, Surface
from plotly.tools import figure_factory as FF

plotly.offline.init_notebook_mode(connected=True)
x, y, z = [], [], []
rois = glob.glob("C:/Users/kiritani/Documents/data/cells/TK577/Anatomy/SurfaceRoi/*.roi")
for f in rois:
    with open(f, 'rb') as fobj:
        roi = ijroi.read_roi(fobj)
        x.append(roi.points[0][0])
        y.append(roi.points[0][1])
        z.append(roi.position)
        
smoothed = Rbf(x, y, z, smooth=1)
vfunc = np.vectorize(smoothed)
X = np.arange(100, 1000)
Y = np.arange(100, 1000)
X, Y = np.meshgrid(X, Y)

fig = plt.figure()
ax = fig.gca(projection='3d')
surf = ax.plot_surface(X*0.6, Y*0.6, vfunc(X, Y)*2.95,
                       linewidth=0, antialiased=False)

rois_neurons = glob.glob("C:/Users/kiritani/Documents/data/cells/TK577/Anatomy/RoiSet/*.roi")

x_neurons, y_neurons, z_neurons = [], [], []
for f in rois_neurons:
    with open(f, 'rb') as fobj:
        roi = ijroi.read_roi(fobj)
        x_neurons.append(roi.points[0][0] * 0.6)
        y_neurons.append(roi.points[0][1] * 0.6)
        z_neurons.append(roi.position * 2.95)
#ax.scatter(x_neurons, y_neurons, z_neurons)
# Out:
# <img src="data:image/png;base64,...">

# %%
import ipyvolume.pylab as p3
fig = p3.figure()
sc1 = p3.scatter(np.array(x_neurons), np.array(y_neurons), np.array(z_neurons), marker='sphere', size=1)
#sc2 = p3.scatter(np.array(x_neurons), np.array(y_neurons), np.array(z_neurons)/5, color='blue', marker='box',size=1)
pia = p3.scatter(X.flatten()[::5] * 0.6, Y.flatten()[::5] * 0.6, vfunc(X.flatten(), Y.flatten())[::5]*2.95, color='blue', marker='box', size=0.5)
p3.xlim(-200, 800)
p3.ylim(-200, 800)
p3.zlim(0, 1000)
p3.show()

# %%
import ipyvolume
import numpy as np
x, y, z = np.random.random((3, 10000))
ipyvolume.quickscatter(x, y, z, size=1, marker="sphere")

# %%
def tri_indices(simplices):
    #simplices is a numpy array defining the simplices of the triangularization
    #returns the lists of indices i, j, k
    
    return ([triplet[c] for triplet in simplices] for c in range(3))

def plotly_trisurf(x, y, z, simplices, plot_edges=None):
    #x, y, z are lists of coordinates of the triangle vertices 
    #simplices are the simplices that define the triangularization;
    #simplices  is a numpy array of shape (no_triangles, 3)
    #insert here the  type check for input data
    from functools import reduce
    #from go import Data
    from plotly.graph_objs import Data
    
    points3D=np.vstack((x,y,z)).T
    tri_vertices=map(lambda index: points3D[index], simplices)# vertices of the surface triangles     
    zmean=[np.mean(tri[:,2]) for tri in tri_vertices ]# mean values of z-coordinates of 
                                                      #triangle vertices
    min_zmean=np.min(zmean)
    max_zmean=np.max(zmean)  
    #facecolor=[map_z2color(zz,  colormap, min_zmean, max_zmean) for zz in zmean] 
    I,J,K=tri_indices(simplices)
    
    triangles=go.Mesh3d(x=x,
                     y=y,
                     z=z, 
                     i=I,
                     j=J,
                     k=K,
                     name='',
                        opacity=0.5
                    )
    
    if plot_edges is None:# the triangle sides are not plotted 
        return Data([triangles])
    else:
        #define the lists Xe, Ye, Ze, of x, y, resp z coordinates of edge end points for each triangle
        #None separates data corresponding to two consecutive triangles
        lists_coord=[[[T[k%3][c] for k in range(4)]+[ None]   for T in tri_vertices]  for c in range(3)]
        Xe, Ye, Ze=[reduce(lambda x,y: x+y, lists_coord[k]) for k in range(3)]
        
        #define the lines to be plotted
        lines=Scatter3d(x=Xe,
                        y=Ye,
                        z=Ze,
                        mode='lines',
                        line=Line(color= 'rgb(50,50,50)', width=1.5)
               )
        return Data([triangles, lines])

# %%
rois_neurons = glob.glob("C:/Users/kiritani/Documents/data/cells/TK577/Anatomy/RoiSet/*.roi")
x_neurons, y_neurons, z_neurons = [], [], []
for f in rois_neurons:
    with open(f, 'rb') as fobj:
        roi = ijroi.read_roi(fobj)
        x_neurons.append(roi.points[0][0] * 0.6)
        y_neurons.append(roi.points[0][1] * 0.6)
        z_neurons.append(roi.position * -2.95)

x_pia, y_pia, z_pia = [], [], []
rois = glob.glob("C:/Users/kiritani/Documents/data/cells/TK577/Anatomy/SurfaceRoi/*.roi")
for f in rois:
    with open(f, 'rb') as fobj:
        roi = ijroi.read_roi(fobj)
        x_pia.append(roi.points[0][0] * 0.6)
        y_pia.append(roi.points[0][1] * 0.6)
        z_pia.append(roi.position * -2.95)
        
smoothed = Rbf(x_pia, y_pia, z_pia, smooth=1)
vfunc = np.vectorize(smoothed)
X = np.arange(100, 600)
Y = np.arange(100, 600)
X, Y = np.meshgrid(X, Y)
Z=vfunc(X, Y)[::5, ::5]

#x_barrel, y_barrel, z_barrel = [], [], []
#rois = glob.glob("C:/Users/kiritani/Documents/data/cells/TK577/Anatomy/Barrel/*.roi")
#for f in rois:
#    with open(f, 'rb') as fobj:
#        roi = ijroi.read_roi(fobj)
#        x_barrel.append(roi.points[:, 0])
#        y_barrel.append(roi.points[:, 1])
#        z_barrel.append(roi.position)
        
barrel = tifffile.imread("C:/Users/kiritani/Documents/data/cells/TK577/Anatomy/barrel.tif")
vertices, simplices = measure.marching_cubes_lewiner(barrel, 120, step_size=5)[0:2]
z_barrel, y_barrel, x_barrel = zip(*vertices)
z_barrel = -2.95 * np.array(z_barrel)
x_barrel = 0.6 * np.array(x_barrel)
y_barrel = 0.6 * np.array(y_barrel)

# %%
neurons = go.Scatter3d(
    x=x_neurons,
    y=y_neurons,
    z=z_neurons,
    mode='markers',
    marker=dict(
        size=2,
        line=dict(
            color='rgba(217, 217, 217, 0.14)',
            width=0.5
        ),
        opacity=0.8
    )
)

pia = go.Surface(x=np.arange(100, 1000)[::5],
                    y=np.arange(100, 1000)[::5],
                    z=Z,
                    opacity=0.8,)

#line_marker = dict(color='#0066FF', width=2)
#lines = []
#for i in range(15):
#    lines.append(go.Scatter3d(x=x_barrel[i]*0.6, y=y_barrel[i]*0.6, z=z_barrel[i] * np.ones(len(x_barrel[i]))*2.95, mode='lines', line=line_marker))

barrel_vol = plotly_trisurf(x_barrel, y_barrel, z_barrel, simplices, plot_edges=None)

data = [neurons, pia,] + barrel_vol

layout = go.Layout(
    margin=dict(
        l=0,
        r=0,
        b=0,
        t=0),
    scene=dict(aspectmode='cube'
            ))

#fig = go.Figure(data=data, layout=layout)
#plotly.offline.iplot(fig, )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-07630ea133a4> in <module>()
#      24 #    lines.append(go.Scatter3d(x=x_barrel[i]*0.6, y=y_barrel[i]*0.6, z=z_barrel[i] * np.ones(len(x_barrel[i]))*2.95, mode='lines', line=line_marker))
#      25
# ---> 26 barrel_vol = plotly_trisurf(x_barrel, y_barrel, z_barrel, simplices, plot_edges=None)
#      27
#      28 data = [neurons, pia,] + barrel_vol
#
# NameError: name 'plotly_trisurf' is not defined

# %% [markdown]
# Now, the all objects are rotated around z and x axis.

# %%
theta1 = 42 / 180 * np.pi
theta2 = -13 /180 * np.pi
rot_mat = np.matrix([[np.cos(theta1), -1 * np.sin(theta1), 0], [np.sin(theta1), np.sin(theta1), 0], [0, 0, 1]]) * np.matrix([[np.cos(theta1), 0, -1 * np.sin(theta2)], [0, 1, 0], [np.sin(theta2), 0, np.cos(theta2)]])

Neurons = rot_mat * np.matrix(np.vstack((x_neurons, y_neurons, z_neurons)))

Pia = rot_mat * np.matrix(np.vstack((x_pia, y_pia, z_pia)))
smoothed = Rbf(Pia.A[0], Pia.A[1], Pia.A[2], smooth=1)
vfunc = np.vectorize(smoothed)
x_mesh = np.arange(200, -400, -5)
y_mesh = np.arange(100, 600, 5)
z_mesh = vfunc(*np.meshgrid(x_mesh, y_mesh))

Barrel = rot_mat * np.matrix(np.vstack((x_barrel, y_barrel, z_barrel)))

# %%
neurons = go.Scatter3d(
    x=Neurons.A[0],
    y=Neurons.A[1],
    z=Neurons.A[2],
    mode='markers',
    marker=dict(
        size=2,
        line=dict(
            color='rgba(217, 217, 217, 0.14)',
            width=0.5
        ),
        opacity=0.8
    )
)

pia = go.Surface(x=x_mesh,
                    y=y_mesh,
                    z=z_mesh,
                    opacity=0.8,)

layout = go.Layout(
    margin=dict(
        l=0,
        r=0,
        b=0,
        t=0),
    scene=dict(aspectmode='cube'
            ))

fig = go.Figure(data=[neurons, pia], layout=layout)
plotly.offline.iplot(fig, )
# Out:
# <div id="94e82fed-c23b-43e5-9896-b916c8b998ea" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("94e82fed-c23b-43e5-9896-b916c8b998ea", [{"mode": "markers", "y": [250.3726069689133, 333.7190877662149, 438.9150545986322, 315.5013058801569, 319.5998187871443, 106.57747269183818, 207.05544393009538, 504.5231818155661, 301.913699422686, 221.67095968806132, 414.19995997169906, 371.91141045787737, 281.33400270981855, 379.967290752057, 252.30322937072606, 378.69288974113226, 361.60754634705916, 357.41893111284776, 246.8673042897076, 383.6764458557241, 211.84752979224467, 383.62179157452505, 229.67797269267157, 457.27005619414115, 460.20932852493877, 467.56466516100727, 332.6163771591132, 82.6143160192111, 477.87457103225665, 316.47956089538764, 357.31616361146723, 586.3217265100609, 313.89990880702203, 483.
# ...

# %%
Neurons.A[0]
# Out:
# array([ 231.24013634,  187.53566166,   74.399996  , ..., -311.97227649,
#        -392.46097662, -501.99707183])

# %%
from matplotlib import path
p = path.Path([(0,0), (0, 1), (1, 1), (1, 0), (0.5, 0.5)])  # square with legs length 1 and bottom left corner at the origin
p.contains_points([(.5, .8)])
# Out:
# array([ True], dtype=bool)

# %%
np.arange(-200, -600, -1)
# Out:
# array([-200, -201, -202, -203, -204, -205, -206, -207, -208, -209, -210,
#        -211, -212, -213, -214, -215, -216, -217, -218, -219, -220, -221,
#        -222, -223, -224, -225, -226, -227, -228, -229, -230, -231, -232,
#        -233, -234, -235, -236, -237, -238, -239, -240, -241, -242, -243,
#        -244, -245, -246, -247, -248, -249, -250, -251, -252, -253, -254,
#        -255, -256, -257, -258, -259, -260, -261, -262, -263, -264, -265,
#        -266, -267, -268, -269, -270, -271, -272, -273, -274, -275, -276,
#        -277, -278, -279, -280, -281, -282, -283, -284, -285, -286, -287,
#        -288, -289, -290, -291, -292, -293, -294, -295, -296, -297, -298,
#        -299, -300, -301, -302, -303, -304, -305, -306, -307, -308, -309,
#        -310, -311, -312, -313, -314, -315, -316, -317, -318, -319, -320,
#        -321, -322, -323, -324, -325, -326, -327, -328, -329, -330, -331,
#        -332, -333, -334, -335, -336, -337, -338, -339, -340, -341, -342,
# ...
